# %%
import pandas as pd

# Replace with your actual file path
df = pd.read_feather("../data/race_stats_sca.feather")
# df = df.apply(pd.to_numeric, errors='coerce')

# Preview
df.head()
# Out:
#    Race Number  Passes P1  Passes P2  Collisions  Choices  \
# 0            1          0          1           0       30
# 1            2          0          1           0       30
# 2            3          0          1           0       30
# 3            4          0          1           0       30
# 4            5          0          1           0       30
#
#    Proportion Ahead P1  Proportion Ahead P2  Win P1  Win P2  Progress P1  ...  \
# 0                 0.27                 0.73   False    True            3  ...
# 1                 0.43                 0.57   False    True            3  ...
# 2                 0.43                 0.57   False    True            3  ...
# 3                 0.43                 0.57   False    True            3  ...
# 4                 0.43                 0.57   False    True            3  ...
#
#    Initial Y Position P2  Theta_a1  Theta_b1  Theta_c1  Theta_a2  Theta_b2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Race Number            500 non-null    int64
#  1   Passes P1              500 non-null    int64
#  2   Passes P2              500 non-null    int64
#  3   Collisions             500 non-null    int64
#  4   Choices                500 non-null    int64
#  5   Proportion Ahead P1    500 non-null    float64
#  6   Proportion Ahead P2    500 non-null    float64
#  7   Win P1                 500 non-null    bool
#  8   Win P2                 500 non-null    bool
#  9   Progress P1            500 non-null    int64
#  10  Progress P2            500 non-null    int64
#  11  Out of Bounds P1       500 non-null    int64
#  12  Out of Bounds P2       500 non-null    int64
#  13  Progress Cost P1       500 non-null    float64
# ...

# %%
print(df['Theta_a1'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 495    1
# 496    1
# 497    1
# 498    1
# 499    1
# Name: Theta_a1, Length: 500, dtype: int64

# %%
# df['A1_1_1'].value_counts

# %%
df.describe()
# Out:
#        Race Number  Passes P1  Passes P2  Collisions  Choices  \
# count   500.000000      500.0  500.00000       500.0    500.0
# mean    250.500000        0.0    0.63600         0.0     30.0
# std     144.481833        0.0    0.48163         0.0      0.0
# min       1.000000        0.0    0.00000         0.0     30.0
# 25%     125.750000        0.0    0.00000         0.0     30.0
# 50%     250.500000        0.0    1.00000         0.0     30.0
# 75%     375.250000        0.0    1.00000         0.0     30.0
# max     500.000000        0.0    1.00000         0.0     30.0
#
#        Proportion Ahead P1  Proportion Ahead P2  Progress P1  Progress P2  \
# count           500.000000           500.000000   500.000000   500.000000
# mean              0.693400             0.304200     2.920000     4.318000
# std               0.270728             0.270345     0.354756     3.309801
# min               0.270000             0.000000     1.000000     0.000000
# ...

# %%
print(df.dtypes)
# Out:
# Race Number                int64
# Passes P1                  int64
# Passes P2                  int64
# Collisions                 int64
# Choices                    int64
# Proportion Ahead P1      float64
# Proportion Ahead P2      float64
# Win P1                      bool
# Win P2                      bool
# Progress P1                int64
# Progress P2                int64
# Out of Bounds P1           int64
# Out of Bounds P2           int64
# Progress Cost P1         float64
# Progress Cost P2         float64
# Bounds Cost P1           float64
# Bounds Cost P2           float64
# Proximity Cost P1        float64
# Proximity Cost P2        float64
# Initial X Position P1      int64
# Initial Y Position P1      int64
# Initial X Position P2      int64
# Initial Y Position P2      int64
# Theta_a1                   int64
# Theta_b1                   int64
# Theta_c1                   int64
# Theta_a2                 float64
# Theta_b2                 float64
# ...

# %%
import matplotlib.pyplot as plt
from pathlib import Path

# extra code – code to save the figures as high-res PNGs for the book

IMAGES_PATH = Path() / "images"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# extra code – the next 5 lines define the default font sizes
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# axes = df[["A1_1_1", "B1_2_4", "C1_6_7", "A2_1_1", "B2_2_4", "C2_6_7",
#            "Theta_a1", "action1", "action2", "State1_x", "State1_y",
#            "State1_v", "State1_phi", "State1_b", "State2_x", "State2_y",
#            "State2_v", "State2_phi", "State2_b"]].hist(bins=50, figsize=(12, 8))

axes = df[["Progress Cost P2", "Bounds Cost P2", "Proximity Cost P2", "Initial X Position P2"]].hist(bins=50, figsize=(12, 8))

for ax in axes.ravel():
    ax.set_xlabel("Value")
    ax.set_ylabel("Frequency")

save_fig("attribute_histogram_plots")
plt.show()

# %%
print(df[['Theta_a1', 'Theta_b1', 'Theta_c1']].isnull().sum())
df = df.dropna()
print(df[['Theta_a1', 'Theta_b1', 'Theta_c1']].isnull().sum())
# Out:
# Theta_a1    0
# Theta_b1    0
# Theta_c1    0
# dtype: int64
# Theta_a1    0
# Theta_b1    0
# Theta_c1    0
# dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = px.scatter_3d(df, 
                    x='Theta_a2', 
                    y='Theta_b2', 
                    z='Theta_c2',
                    color='Passes P2',
                    size='Theta_a2',
                    title='3D Plot: Weights and Passes')

# Correct way to update marker properties
fig.update_traces(marker=dict(sizemin=3))  # Only sizemin works here
fig.show()

# %%
import numpy as np

cleaned_data = df.drop(['action2', 'Theta_a2', 'Theta_b2', 'Theta_c2', 'Action_space1', 'Action_space2', "State1_x", "State1_y",
                     "State1_v", "State1_phi", "State1_b", "State2_x", "State2_y",
                     "State2_v", "State2_phi", "State2_b"], axis=1)

cleaned_data = cleaned_data.drop(cleaned_data.filter(regex='^A2_').columns, axis=1)
cleaned_data = cleaned_data.drop(cleaned_data.filter(regex='^B2_').columns, axis=1)
cleaned_data = cleaned_data.drop(cleaned_data.filter(regex='^C2_').columns, axis=1)


def shuffle_and_split_data(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

train_set, test_set = shuffle_and_split_data(cleaned_data, 0.2)
print(len(train_set))
print(len(test_set))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 3
#       1 import numpy as np
# ----> 3 cleaned_data = df.drop(['action2', 'Theta_a2', 'Theta_b2', 'Theta_c2', 'Action_space1', 'Action_space2', "State1_x", "State1_y",
#       4                      "State1_v", "State1_phi", "State1_b", "State2_x", "State2_y",
#       5                      "State2_v", "State2_phi", "State2_b"], axis=1)
#       7 cleaned_data = cleaned_data.drop(cleaned_data.filter(regex='^A2_').columns, axis=1)
#       8 cleaned_data = cleaned_data.drop(cleaned_data.filter(regex='^B2_').columns, axis=1)
#
# File c:\Users\toazb\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
# ...

# %%
cleaned_data.head()

# %%
np.random.seed(42)

# %%
corr_matrix = train_set.corr(numeric_only=True)
corr_matrix["action1"].sort_values(ascending=False)

# %%
from pandas.plotting import scatter_matrix

attributes = ["action1", "Theta_a1", "Theta_b1", "Theta_c1", "B1_4_1", "B1_9_4"]
scatter_matrix(train_set[attributes], figsize=(12, 8))
save_fig("scatter_matrix_plot")  # extra code
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

train_features = train_set.drop(['Theta_a1', 'Theta_b1', 'Theta_c1'], axis=1)
train_labels = train_set[['Theta_a1', 'Theta_b1', 'Theta_c1']]

std_scaler = StandardScaler()
scaled_train_set = std_scaler.fit_transform(train_labels)

kernel = 1 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e2))
gaussian_process = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
gaussian_process.fit(train_features, train_labels)
gaussian_process.kernel_
